# %% [markdown]
# # Matplotlib API

# %%
# %pylab
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
plot(np.arange(10))

# %% [markdown]
# ## Figure && Subplot
# ### matplotlib图像都位于figure对象中

# %%
fig = plt.figure() # 创建figure对象 opt:  figsize 控制图片大小和横纵比（figure相当于面板）

# %%
ax1 = fig.add_subplot(2,2,1)  #不能通过figure绘图，通过add_subplot创建subplot （长，宽，编号）

# %%
from numpy.random import randn

# %%
plt.plot(randn(50).cumsum(),'k--')

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(randn(50).cumsum(),'k--')    #k-- 线型选项，为黑色虚线

# %%
h = ax1.hist(randn(100),bins=20,color='k',alpha = 0.3)

# %%
 ax2.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig

# %%
fig2, axes = plt.subplots(2,3)  #更方便创建figure

# %%
axes[0,1]

# %%
fig,axes = plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500),bins=50,color='k',alpha=0.5)
plt.subplots_adjust(wspace=0.3,hspace=0.3)  # 利用subplots_adjust()调整图像间的间距 ！！matplotlib不检查标签重叠

# %% [markdown]
# ### plot函数可以接受一组x,y坐标，一个颜色变量和一个线型变量

# %%
plt.plot(0,0,linestyle='--',color='g')

# %%
plot(randn(30).cumsum(),color='g',linestyle='dashed',marker='o')  #marker强调实际数据点

# %% [markdown]
# ## 设置标题、轴标签、刻度以及刻度标签

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(),'k',label='one')

# %%
ticks = ax.set_xticks([0,250,500,750,1000])    #将刻度放在数据范围那些位置

# %%
labels = ax.set_xticklabels(['one','tow','three','four','five'],rotation=30,fontsize = 'small') #将刻度替换为指定标签

# %%
ax.set_title('My Test')   #设置标题
ax.set_xlabel('Stages')   #设置X轴名称

# %%
fig

# %% [markdown]
# ## 添加图例(legend)

# %%
ax.plot(randn(1000).cumsum(),'g--',label = 'two')

# %%
ax.plot(randn(1000).cumsum(),'k.',label = 'three')

# %%
ax.legend(loc = 'best') #loc 设定图例放置位置

# %%
fig

# %% [markdown]
# ## 图表保存

# %%
plt.savefig('tubiao.png',dpi=400,bbox_inches='tight')

# %% [markdown]
# # Pandas 绘图函数

# %% [markdown]
# ## 线型图

# %%
import pandas as pd

# %%
s = pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
